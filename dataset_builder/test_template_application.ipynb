# %%
import sys
sys.path.append('../core')
from ReactChemChecker import *

# %%
smiles1 = 'C#C[C@]1(COP(=O)([O-])[O-])O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O.O>>C#C[C@]1([C@H](C[C@@H](O1)N2C=NC3=C(N=C(N=C32)F)N)O)CO'
smiles2 = "C#C[C@]1(COP(=O)([O-])[O-])O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O.O>>C#C[C@]1([C@H](C[C@@H](O1)N2C=NC3=C(N=C(N=C32)F)N)O)CO"
temp = template_extractor(smiles1, debug=True)
reaction_chemistry_checker(temp, smiles2, debug=True)
# Out:
# Reaction for Template Extraction: C#C[C@]1(COP(=O)([O-])[O-])O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O.O>>C#C[C@]1(CO)O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x300>
# Forward template: (O=P(-[O-])(-[O-])-[O;H0;D2;+0:1]-[C:2])>>([C:2]-[OH;D1;+0:1])
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x300>
# Reaction for Template Application: C#C[C@]1(COP(=O)([O-])[O-])O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O.O>>C#C[C@]1(CO)O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x300>
# Reactants that will undergo template application: C#C[C@]1(COP(=O)([O-])[O-])O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O.O
# Outcome 0 SMILES: C#C[C@]1(CO)O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O
# Correct outcome identified: C#C[C@]1(CO)O[C@@H](n2cnc3c(N)nc(F)nc32)C[C@@H]1O
# (True, 'rdchiral')
